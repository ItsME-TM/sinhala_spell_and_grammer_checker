# %% [markdown]
# # Spell-Checker (DATASET 1)

# %% [markdown]
# ## Sinhala dataset

# %%
import pandas as pd
import re
import textdistance

def load_dataset():
    #load dataset
    dataset_path = "Dataset/sinhala_dataset.csv"
    data = pd.read_csv(dataset_path)
    print(data.head())
    return data

def tokenize_sentence(sentence):
    #split into words
    return re.findall(r'\b[^\s]+\b', sentence)

def correct_word(word, dictionary):
    # Compute Levenshtein distance for each word in the dictionary
    distances = [(candidate, textdistance.levenshtein(word, candidate)) for candidate in dictionary]
    # Sort by distance (ascending)
    distances = sorted(distances, key=lambda x: x[1])
    # Return the closest match
    return distances[0][0] if distances else word

def correct_sentence(tokens, dictionary):
    corrected_tokens = [correct_word(token, dictionary) for token in tokens]
    return ' '.join(corrected_tokens)

data = load_dataset()
# Tokenize the original and spelling error sentences
data['Original Tokens'] = data['Original Sentence'].apply(tokenize_sentence)
data['Spelling Error Tokens'] = data['Spelling Error'].apply(tokenize_sentence)
print(data[['Original Tokens', 'Spelling Error Tokens']].head())

# Create a dictionary of unique words from the original sentences
unique_words = set(word for sentence in data['Original Tokens'] for word in sentence)

# Test the correction function
sample_error = data['Spelling Error Tokens'][0]
corrected = correct_sentence(sample_error, unique_words)
print("Original Error:", sample_error)
print("Corrected Sentence:", corrected)
# Out:
#                                    Original Sentence  \
# 0  කතානායක අශෝක රංවලගේ අධ්යාපන සුදුසුකම් පිළිබඳ ම...
# 1  දෙසැම්බර් වන දා සිය ධූරයෙන් ඉල්ලා අස්වීමත් සමඟ...
# 2  ඉල්ලා අස්වීම ජනධිපතිවරයා විසින් භාර ගැනීමත් සම...
# 3  නොවැම්බර් වැනි දා ඔහු කාතානායක ධුරයට පත් වූ දා...
# 4  අශෝක රංවල විසින් නිකුත් කළ මාධ්ය නිවේදනයක් දෙස...
#
#                                       Spelling Error  \
# 0  කතාානයක අශෝක රංවලගේ අධය්ාපන සුදුසුකම් පිළිබඳ ම...
# 1  දෙසැමබ්ර් වන දා සිය ධූරයෙන් ඉල්ාල අස්වීමත් සමඟ...
# 2  ඉල්ාල අස්වමී ජනධිපතිවරයා විසින් භාර ගැනීමත් සම...
# 3  නොවැම්බර් වැනි ාද හඔු කාතානායක ධුරයට පත් වූ ාද...
# 4  අශෝක ංරවල විසින් නිකුත් කළ මාධ්ය නිවේදනයක් දෙස...
#
#                                        Grammar Error
# 0  කතානායක අශෝක රංවලගේ අධ්යාපන සුදුසුකම් පිළිබඳ ම...
# 1  දෙසැම්බර් වන දා සිය ධූරයෙන් ඉල්ලා අස්වීමත් සමඟ...
# 2  ඉල්ලා අස්වීම ජනධිපතිවරයා විසින් භාර ගැනීමත් සම...
# 3  නොවැම්බර් වැනි දා ඔහු කාතානායක ධුරයට එක පත් වූ...
# 4  අශෝක රංවල විසින් නිකුත් කළ මාධ්ය වැනිදා දෙසැම්...
#                                      Original Tokens  \
# 0  [කතානායක, අශෝක, රංවලග, අධ්යාපන, සුදුසුකම, පිළි...
# 1  [දෙසැම්බර, වන, ද, සිය, ධූරයෙන, ඉල්ල, අස්වීමත, ...
# 2  [ඉල්ල, අස්වීම, ජනධිපතිවරය, විසින, භාර, ගැනීමත,...
# 3  [නොවැම්බර, වැන, ද, ඔහ, කාතානායක, ධුරයට, පත, ව,...
# 4  [අශෝක, රංවල, විසින, නිකුත, කළ, මාධ්ය, නිවේදනයක...
#
#                                Spelling Error Tokens
# 0  [කතාානයක, අශෝක, රංවලග, අධය්ාපන, සුදුසුකම, පිළි...
# 1  [දෙසැමබ්ර, වන, ද, සිය, ධූරයෙන, ඉල්ාල, අස්වීමත,...
# 2  [ඉල්ාල, අස්වම, ජනධිපතිවරය, විසින, භාර, ගැනීමත,...
# 3  [නොවැම්බර, වැන, ද, හඔ, කාතානායක, ධුරයට, පත, ව,...
# 4  [අශෝක, රවල, විසින, නිකුත, කළ, මාධ්ය, නිවේදනයක,...
# Original Error: ['කතාානයක', 'අශෝක', 'රංවලග', 'අධය්ාපන', 'සුදුසුකම', 'පිළිබඳ', 'මත', 'ව', 'ආනද්ෝලනය', 'පෙර', 'නොව', 'විර', 'ජනවරමකින', 'බලයට', 'පත', 'ජාතක', 'ජනබලවේග', 'ආණඩ්වුට', 'මසක', 'ගතවීමටත', 'පෙර', 'තම', 'කුළදුුල', 'ආණ්ඩුව', 'සුජාතභාවය', 'ආරක්ෂාකර', 'ගනීැමට', 'මුුහණ', 'දීමට', 'සිද', 'ව', 'අභියෝගාත්මක', 'ලිට්මස', 'පරීක්ෂාවක', 'බවට', 'පත්විය']
# Corrected Sentence: කතානායක අශෝක රංවලග අධ්යාපන සුදුසුකම පිළිබඳ මත ව ආන්දෝලනය පෙර නොව විර ජනවරමකින බලයට පත ජාතික ජනබලවේග ආණ්ඩුව මසක ගතවීමටත පෙර තම කුළුදුල ආණ්ඩුව සුජාතභාවය ආරක්ෂාකර ගැනීමට මුහුණ දීමට සිද ව අභියෝගාත්මක ලිට්මස පරීක්ෂාවක බවට පත්විය

# %%
# Apply the spell checker to all sentences with spelling errors
data['Corrected Spelling Error'] = data['Spelling Error Tokens'].apply(lambda x: correct_sentence(x, unique_words))

# Evaluate the corrections
print(data[['Spelling Error', 'Corrected Spelling Error', 'Original Sentence']].head())
# Out:
#                                       Spelling Error  \
# 0  කතාානයක අශෝක රංවලගේ අධය්ාපන සුදුසුකම් පිළිබඳ ම...
# 1  දෙසැමබ්ර් වන දා සිය ධූරයෙන් ඉල්ාල අස්වීමත් සමඟ...
# 2  ඉල්ාල අස්වමී ජනධිපතිවරයා විසින් භාර ගැනීමත් සම...
# 3  නොවැම්බර් වැනි ාද හඔු කාතානායක ධුරයට පත් වූ ාද...
# 4  අශෝක ංරවල විසින් නිකුත් කළ මාධ්ය නිවේදනයක් දෙස...
#
#                             Corrected Spelling Error  \
# 0  කතානායක අශෝක රංවලග අධ්යාපන සුදුසුකම පිළිබඳ මත ...
# 1  දෙසැම්බර වන ද සිය ධූරයෙන ඉල්ල අස්වීමත සමඟ ශ්ර ...
# 2  ඉල්ල අස්වන ජනධිපතිවරය විසින භාර ගැනීමත සමග ඔහු...
# 3  නොවැම්බර වැන ද හර කාතානායක ධුරයට පත ව ද පටන්ම ...
# 4  අශෝක වල විසින නිකුත කළ මාධ්ය නිවේදනයක දෙසැම්බර...
#
#                                    Original Sentence
# 0  කතානායක අශෝක රංවලගේ අධ්යාපන සුදුසුකම් පිළිබඳ ම...
# 1  දෙසැම්බර් වන දා සිය ධූරයෙන් ඉල්ලා අස්වීමත් සමඟ...
# 2  ඉල්ලා අස්වීම ජනධිපතිවරයා විසින් භාර ගැනීමත් සම...
# 3  නොවැම්බර් වැනි දා ඔහු කාතානායක ධුරයට පත් වූ දා...
# 4  අශෝක රංවල විසින් නිකුත් කළ මාධ්ය නිවේදනයක් දෙස...

# %%
def calculate_accuracy(original_sentences, corrected_sentences):
    # Initialize counters
    word_correct = 0
    word_total = 0
    sentence_correct = 0
    sentence_total = len(original_sentences)

    for original, corrected in zip(original_sentences, corrected_sentences):
        # Tokenize both sentences
        original_tokens = tokenize_sentence(original)
        corrected_tokens = tokenize_sentence(corrected)
        
        # Word-level accuracy
        for orig_word, corr_word in zip(original_tokens, corrected_tokens):
            word_total += 1
            if orig_word == corr_word:
                word_correct += 1

        # Sentence-level accuracy
        if original == corrected:
            sentence_correct += 1

    # Calculate percentages
    word_accuracy = (word_correct / word_total) * 100 if word_total > 0 else 0
    return word_accuracy

# Evaluate accuracy of the spell checker
original_sentences = data['Original Sentence']
corrected_sentences = data['Corrected Spelling Error']

word_accuracy = calculate_accuracy(original_sentences, corrected_sentences)
print(f"Word-Level Accuracy: {word_accuracy:.2f}%")
# Out:
# Word-Level Accuracy: 90.95%

# %%
def correct_word(word, dictionary):
    # Compute Levenshtein distance for each word in the dictionary
    distances = [(candidate, textdistance.levenshtein(word, candidate)) for candidate in dictionary]
    # Sort by distance (ascending)
    distances = sorted(distances, key=lambda x: x[1])
    # Return the closest match
    return (word, distances[0][0]) if distances else (word, word)  # Return the original word if no match found

def correct_sentence(tokens, dictionary):
    # Correct each word and collect mistakes
    corrections = [correct_word(token, dictionary) for token in tokens]
    corrected_tokens = [correct[1] for correct in corrections]
    mistakes = [(original, corrected) for original, corrected in corrections if original != corrected]
    return ' '.join(corrected_tokens), mistakes

# Apply the spell checker and collect mistakes
data['Corrected Spelling Error'], data['Mistakes'] = zip(
    *data['Spelling Error Tokens'].apply(lambda x: correct_sentence(x, unique_words))
)

# Print spelling mistakes and corrections
for index, row in data.iterrows():
    print(f"Sentence {index + 1}:")
    print(f"  Spelling Mistakes and Corrections: {row['Mistakes']}")
    print(f"  Corrected Sentence: {row['Corrected Spelling Error']}")
    print()
# Out:
# Sentence 1:
#   Spelling Mistakes and Corrections: [('කතාානයක', 'කතානායක'), ('අධය්ාපන', 'අධ්යාපන'), ('ආනද්ෝලනය', 'ආන්දෝලනය'), ('ජාතක', 'ජාතික'), ('ආණඩ්වුට', 'ආණ්ඩුව'), ('කුළදුුල', 'කුළුදුල'), ('ගනීැමට', 'ගැනීමට'), ('මුුහණ', 'මුහුණ')]
#   Corrected Sentence: කතානායක අශෝක රංවලග අධ්යාපන සුදුසුකම පිළිබඳ මත ව ආන්දෝලනය පෙර නොව විර ජනවරමකින බලයට පත ජාතික ජනබලවේග ආණ්ඩුව මසක ගතවීමටත පෙර තම කුළුදුල ආණ්ඩුව සුජාතභාවය ආරක්ෂාකර ගැනීමට මුහුණ දීමට සිද ව අභියෝගාත්මක ලිට්මස පරීක්ෂාවක බවට පත්විය
#
# Sentence 2:
#   Spelling Mistakes and Corrections: [('දෙසැමබ්ර', 'දෙසැම්බර'), ('ඉල්ාල', 'ඉල්ල'), ('ශ්ීර', 'ශ්ර'), ('අඩම', 'අඩුම')]
#   Corrected Sentence: දෙසැම්බර වන ද සිය ධූරයෙන ඉල්ල අස්වීමත සමඟ ශ්ර ලංක ඉතිහාසය අඩුම කාලයක කතානායක ධුරය දැර කතානායකවරය බවට අශෝක රංවල පත්විය
#
# Sentence 3:
#   Spelling Mistakes and Corrections: [('ඉල්ාල', 'ඉල්ල'), ('අස්වම', 'අස්වන'), ('රධ', 'ර')]
#   Corrected Sentence: ඉල්ල අස්වන ජනධිපතිවරය විසින භාර ගැනීමත සමග ඔහුග ර කාලය දින කට සීම වුණ
#
# Sentence 4:
#   Spelling Mistakes and Corrections: [('හඔ', 'හර'), ('වවිධ', 'විවිධ'), ('මා්ධය', 'මාධ්ය'), ('යඑ', 'යම'), ('වඅසානය', 'අවසානය'), ('අස්ීවමට', 'අස්වීමට'), ('තමර', 'තම'), ('බලෑපමක', 'බලපෑමක'), ('ඇිත', 'ඇවිත')]
#   Corrected Sentence: නොවැම්බර වැන ද හර කාතානායක ධුරයට පත ව ද පටන්ම ඔහුග අධ්යාපන සුදුසුකම පිළිබඳව විවිධ පුද්ගලයින සමාජ මාධ්ය ඔස්ස ප්රශ්න කරන්නට විය යම අවසානය කෙළවර වූය අශෝක රන්වලට ධුරයෙන ඉල්ල අස්වීමට තම බරපතල සමාජ බලපෑමක ඇවිත කරමින
#
# Sentence 5:
#   Spelling Mistakes and Corrections: [('රවල', 'වල'), ('දෙසැමබ්ර', 'දෙසැම්බර'), ('වැනිාද', 'වැනිද'), ('මා්ධය', 'මාධ්ය'), ('ලබීය', 'ලැබීය')]
#   Corrected Sentence: අශෝක වල විසින නිකුත කළ මාධ්ය නිවේදනයක දෙසැම්බර වැනිද ජාතික ජනබලවේගය මාධ්ය අංශය විසින මාධ්ය වෙත නිකුත කරන ලැබීය
#
# Sentence 6:
#   Spelling Mistakes and Corrections: [('නිවදේනය', 'නිවේදනය')]
#   Corrected Sentence: එම නිවේදනය මෙස ය
#
# Sentence 7:
#   Spelling Mistakes and Corrections: [('පසුිගය', 'පසුගිය'), ('කහිිපය', 'කිහිපය'), ('පිළබිඳ', 'පිළිබඳ'), ('තළ', 'තුළ')]
#   Corrected Sentence: පසුගිය දින කිහිපය තුළ මාග අධ්යාපන සුදුසුකම පිළිබඳ ගැටලුවක සමාජය තුළ මත කරන ලැබ තිබ
#
# Sentence 8:
#   Spelling Mistakes and Corrections: [('ප්කරාශයක', 'ප්රකාශයක'), ('නත', 'ගත')]
#   Corrected Sentence: මාග අධ්යාපන සුදුසුකම පිළිබඳ කිසිද සාවද්ය ප්රකාශයක ම විසින ප්රකාශ කර ගත
#
# Sentence 9:
#   Spelling Mistakes and Corrections: [('මඑ', 'මහ'), ('ලියකියවිිල', 'ලියකියවිල'), ('මහොත', 'මොහොත')]
#   Corrected Sentence: එහෙත එම අධ්යාපන සුදුසුකම තහවුර කිරීම සඳහ අවශ්ය සමහර ලියකියවිල ම මොහොත ම සතුව නොමැත බැවින ද මහ ලියකියවිල ම මොහොත කඩිනමින ඉදිරිපත කිරීම දුෂ්කර ව තිබ
#
# Sentence 10:
#   Spelling Mistakes and Corrections: [('ආචරා්ය', 'ආචාර්ය'), ('උපාධය', 'උපාධිය'), ('නඅුබද්ධ', 'අනුබද්ධ'), ('යආතනයන', 'යන්න'), ('ඉදිරපිත', 'ඉදිරිය'), ('වපතින', 'වලින'), ('අරත', 'අත'), ('සැලකි්ලලට', 'සැලකිල්ලට'), ('කරෙහ', 'කරහ'), ('වැැළක්වීම', 'වැළැක්වීම'), ('දනට', 'දැනට'), ('අසව්ීමට', 'අස්වීමට'), ('වබ', 'බ'), ('දම', 'දෙම')]
#   Corrected Sentence: ම හට ආචාර්ය උපාධිය ලබාදුන ජපානය වසීද විශ්වවිද්යාලයට අනුබද්ධ පර්යේෂණ යන්න ඊට අදාළ අධ්යාපන ලියකියවිල ඉදිරිය කිරීම හැකියාව වලින අත ඒව හැක ඉක්මනින ඉදිරිපත කිරීමට අදහස කරම කෙස වෙතත මතුව ඇත තත්ත්වය සැලකිල්ලට ගෙන ආණ්ඩුවත අප කරහ විශ්වාසය තබ ජනතාවත අපහසුතාවයට පත්වීම වැළැක්වීම සඳහ ම දැනට දරන කතානායක ධූරයෙන ඉල්ල අස්වීමට තීරණය කළ බ මෙයින දැනුම දෙම
#
# Sentence 11:
#   Spelling Mistakes and Corrections: [('ඔුහ', 'ඔහ'), ('ලපිිය', 'ලිපිය'), ('භරාදුන', 'ලබාදුන'), ('විිසන', 'වලින'), ('යෝනජාවක', 'යෝජනාවක'), ('ආරමභ', 'ආරම්භ')]
#   Corrected Sentence: ඔහ ඉල්ල අස්වීම ලිපිය ලබාදුන දෙසැම්බර වන ද දහවල විපක්ෂය වලින විශ්වාසභංග යෝජනාවක ඉදිරිපත කිරීම සඳහ මන්ත්රීවරුන්ග අත්සන ලබ ගැනීම ආරම්භ කළේය
#
# Sentence 12:
#   Spelling Mistakes and Corrections: [('අශක', 'දශක'), ('ජනාධිතපිවරය', 'ජනාධිපතිවරය'), ('වබ', 'බ'), ('ජානධිපත', 'ජනාධිපත'), ('කුානෂ', 'කුෂාන')]
#   Corrected Sentence: දශක රංවල සිය ධුරයෙන ඉල්ල අස්වීම ජනාධිපතිවරය පිළිගෙන ඇත බ ජනාධිපත ලේකම්වරය විසින පාර්ලිමේන්තුව මහලේකම කුෂාන රෝහණදීර වෙත ලිඛිතව දැනුම්ද ඇත
#
# Sentence 13:
#   Spelling Mistakes and Corrections: [('පතව', 'පත'), ('වබ', 'බ'), ('ලඛිතව', 'ලිඛිතව')]
#   Corrected Sentence: දහවැන පාර්ලිමේන්තුව අභිනව කතානායකවරය ලෙස පත අශෝක රංවල තම ධුරයෙන ඉල්ල අස්වන බ ජනාධිපතිවරයාට ලිඛිතව දැනුම්ද තිබිණ
#
# Sentence 14:
#   Spelling Mistakes and Corrections: [('කාකර', 'කාලය'), ('සාභ', 'සභ'), ('සාභපත', 'සභාපත'), ('වකර', 'විර'), ('වනන', 'වෙන'), ('අත්නස', 'අත්සන'), ('ටයත', 'අය'), ('දැුනම්දිය', 'දැනුම්දිය')]
#   Corrected Sentence: ආණ්ඩුක්රම ව්යවස්ථාව ව්යවස්ථාව අනුව කතානායක නියෝජ්ය කතානායක හ නියෝජ්ය කාලය සභ සභාපත යන විර පදවියකින හ ඉල්ල අස වෙන නම ඒ බව ස්වකීය අත්සන අය ව ලිපියක මගින ජනාධිපතිවරයාට දැනුම්දිය යුත ව
#
# Sentence 15:
#   Spelling Mistakes and Corrections: [('වසිින', 'සිටින'), ('පර්ලිමේන්ත', 'පාර්ලිමේන්ත'), ('ලේක්ම', 'ලේකම')]
#   Corrected Sentence: ඒ අනුව ජනාධිපත ලේකම්වරය සිටින පාර්ලිමේන්තුව මහලේකම්වරියට මම ලිඛිත දැනුම්දීම සිදුකර ඇතැය පාර්ලිමේන්ත මහ ලේකම කාර්යාලය නිවේදනය කළේය
#
# Sentence 16:
#   Spelling Mistakes and Corrections: [('නර්මාල', 'නිර්මාල'), ('සිංලහ', 'සිංහල'), ('කිාය', 'කිය'), ('ළක', 'ඕක'), ('නඅාගතය', 'අනාගතය'), ('පියරවක', 'පියවරක')]
#   Corrected Sentence: ආචාර්ය නිර්මාල රංජිත දේවසිර බීබීස සිංහල වෙත අදහස දක්වමින කිය සිටිය කතානායකවරය සම්බන්ධයෙන රජය කටයුත ඕක ආකාරය ආණ්ඩුව අනාගතය සම්බන්ධයෙන හොඳ පියවරක බවය
#
# Sentence 17:
#   Spelling Mistakes and Corrections: [('මක', 'මහ')]
#   Corrected Sentence: අනාගතය සම්බන්ධයෙන මහ ඉතාම හොඳ දෙයක
#
# Sentence 18:
#   Spelling Mistakes and Corrections: [('ඒකන', 'ඒක'), ('ජනමතටය', 'ජනමතයට')]
#   Corrected Sentence: ඒක තේරුණ ජනමතයට සවන දුන්න කියන එක
#
# Sentence 19:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: විවේචනයක තිබුණාන
#
# Sentence 20:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: මේක ආණ්ඩුවට අපකීර්තියක
#
# Sentence 21:
#   Spelling Mistakes and Corrections: [('දෙකය', 'දෙයක')]
#   Corrected Sentence: හොඳ දෙයක නෙමෙය කියල
#
# Sentence 22:
#   Spelling Mistakes and Corrections: [('පයවර', 'පියවර')]
#   Corrected Sentence: ඒ නිස ම පියවර හොඳ දෙයක
#
# Sentence 23:
#   Spelling Mistakes and Corrections: [('ඔුහ', 'ඔහ'), ('හමජනතාවග', 'මහජනතාවග'), ('දැිඩ', 'දැඩ')]
#   Corrected Sentence: ඔහ පැවසුව වත්මන ආණ්ඩුව මහජනතාවග දැඩ සුපරීක්ෂාවට ලක්ව ඇත බව ය
#
# Sentence 24:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: වැදගත්ම ද තම මේක හොඳ පාඩමක
#
# Sentence 25:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ම ආණ්ඩුව තමය අප කියන්න ඒ කියන්න ඔවුන මහජනයාග සුපරීක්ෂාවට ලක වෙල තියෙනව
#
# Sentence 26:
#   Spelling Mistakes and Corrections: [('මිිදල', 'මිදිල'), ('ගඑොල්නල්ට', 'ගොල්ලන්ට')]
#   Corrected Sentence: ඒ සුපරීක්ෂාවෙන මිදිල කටයුත කරන්න ගොල්ලන්ට බැහ කියල තම මෙකෙන පෙන්නුම කරන්න
#
# Sentence 27:
#   Spelling Mistakes and Corrections: [('ආ්ණඩුව', 'ආණ්ඩුව'), ('පනේනුම', 'පෙන්නුම'), ('ඔුහ', 'ඔහ')]
#   Corrected Sentence: කෙසේවෙතත කතානායකවරය සම්බන්ධයෙන තීරණයක ගැනීමේද ආණ්ඩුව යම මන්දගාම ස්වරූපයක පෙන්නුම කළ බවද ඔහ පෙන්ව දුන්න ය
#
# Sentence 28:
#   Spelling Mistakes and Corrections: [('කයාල', 'කාල')]
#   Corrected Sentence: මම හිතන්න ටිකක කල ගත්ත වැඩිය කාල
#
# Sentence 29:
#   Spelling Mistakes and Corrections: [('මොදක', 'ලොක')]
#   Corrected Sentence: ලොක ඒක ආණ්ඩුවටමය ඩැමේජ එක
#
# Sentence 30:
#   Spelling Mistakes and Corrections: [('වේග', 'වග'), ('ග්තත', 'ගත්තොත'), ('මක', 'මහ'), ('දීාල', 'දීල')]
#   Corrected Sentence: ම වග එකක දැන ගත්තොත ගමන්ම මහ ටෙලිෆෝන කොල එකක දීල චෙක්කර ගන්නව වග වැඩක න
#
# Sentence 31:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: සරලය න
#
# Sentence 32:
#   Spelling Mistakes and Corrections: [('ඉන්ඩිවිුජවල', 'ඉන්ඩිවිජුවල'), ('උනඩ', 'කඩ')]
#   Corrected Sentence: ඉන්ඩිවිජුවල ට්රස්ට එක කඩ වැඩ කරන්න පක්ෂයක
#
# Sentence 33:
#   Spelling Mistakes and Corrections: [('එතකට', 'එතකොට'), ('කඒ', 'කඩ'), ('හකිව', 'හැකිව')]
#   Corrected Sentence: එතකොට ඒ මට්මෙන කඩ විසඳගන්න හැකිව තිබුණ ඔච්චර දුරදිග ගෙනියන්න යන්න නැතිව
#
# Sentence 34:
#   Spelling Mistakes and Corrections: [('පඅකීර්තියක', 'කීර්තියක'), ('ආචාරය', 'ආකාරය'), ('දේවසිිර', 'දේවසිර')]
#   Corrected Sentence: මේකෙන ආණ්ඩුවට ලොක කීර්තියක ආවන ආකාරය නිර්මාල රංජිත දේවසිර කිය සිටියේය
#
# Sentence 35:
#   Spelling Mistakes and Corrections: [('කරනන', 'කරන්න'), ('කයල', 'කාල'), ('කඑ', 'කඩ')]
#   Corrected Sentence: මේක අප වග අයට හොඳය බලපෑම කරල ම වග තීරණ වෙනස කරන්න පුළුවන කාල කියන කඩ
#
# Sentence 36:
#   Spelling Mistakes and Corrections: [('නුමත', 'වුණත')]
#   Corrected Sentence: වුණත ඒක ආණ්ඩුවට හොඳ නැහ
#
# Sentence 37:
#   Spelling Mistakes and Corrections: [('ආණ්ුඩවට', 'ආණ්ඩුවට'), ('මජහන', 'මහජන')]
#   Corrected Sentence: ආණ්ඩුවට තිබුණ මහජන විරෝධය එන්න කලින්ම මේක කරන්න
#
# Sentence 38:
#   Spelling Mistakes and Corrections: [('මට', 'වට'), ('මකෙන', 'මෙකෙන')]
#   Corrected Sentence: එහෙම වුණ නම වට වඩ වැඩිපුර කීර්තියක එනව මෙකෙන
#
# Sentence 39:
#   Spelling Mistakes and Corrections: [('මවර', 'මෙවර'), ('නොනව', 'නොව'), ('පෙන්ාව', 'පෙන්ව'), ('දුන්ේනය', 'දුන්නේය')]
#   Corrected Sentence: ආණ්ඩුවට මෙවර ජනතාව ලබ ද ඇත්ත නිකම්ම ජනවරමක නොව බව ද ඔහ පෙන්ව දුන්නේය
#
# Sentence 40:
#   Spelling Mistakes and Corrections: [('කනරන', 'කරන')]
#   Corrected Sentence: ම ඡන්දය දුන්න ඇවිල්ල ඕන දෙයක කරන නෙම
#
# Sentence 41:
#   Spelling Mistakes and Corrections: [('අගරෙන', 'ගෙන'), ('තම්න', 'තමන')]
#   Corrected Sentence: එහෙම දීල තම රාජපක්ෂල ගෙන තමන හිත හිත ද කළ
#
# Sentence 42:
#   Spelling Mistakes and Corrections: [('නග්න', 'නොවන')]
#   Corrected Sentence: තනතුර කාලය දික්කර නොවන
#
# Sentence 43:
#   Spelling Mistakes and Corrections: [('වනස', 'විස')]
#   Corrected Sentence: ආණ්ඩුක්රම ව්යවස්ථාව අවශ්ය විදිහට විස කරන්න
#
# Sentence 44:
#   Spelling Mistakes and Corrections: [('මේෙකන', 'මෙකෙන'), ('පෙන්නම', 'පෙන්න')]
#   Corrected Sentence: දැන එහෙම බ කියන එන තම මෙකෙන පෙන්න කළ
#
# Sentence 45:
#   Spelling Mistakes and Corrections: [('වවේචනාත්මකව', 'විවේචනාත්මකව')]
#   Corrected Sentence: ගොඩක අය ඉන්නව විවේචනාත්මකව යන
#
# Sentence 46:
#   Spelling Mistakes and Corrections: [('කඑ', 'කඩ'), ('කෙරුාණ', 'කෙරුණ')]
#   Corrected Sentence: එකක තියාගෙන හිටප අය ඉන්නව කියන කඩ මේකෙන හොඳට පෙන්නුම කෙරුණ
#
# Sentence 47:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ඒක හොඳ තත්ත්වයක
#
# Sentence 48:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: හෙතෙම වැඩිදුරටත පැවසීය
#
# Sentence 49:
#   Spelling Mistakes and Corrections: [('කළමනාරකණ', 'කළමනාකරණ'), ('මෙත්සල', 'මෙත්සිල'), ('කනර', 'කවර'), ('ගතවවුහොත', 'ගතවුණොත'), ('ප්රතිරපූයට', 'ප්රතිරූපයට'), ('විශල', 'විශාල')]
#   Corrected Sentence: වයඹ විශ්ව විද්යාලය කළමනාකරණ හ මූල්ය පීඨය මහාචාර්ය අමින්ද මෙත්සිල පෙරේර කිය සිටිය ආණ්ඩුව බොර කවර බව සමාජ ගතවුණොත එය ආණ්ඩුව ප්රතිරූපයට විශාල හානියක විය හැක බව ය
#
# Sentence 50:
#   Spelling Mistakes and Corrections: [('ආ්ණඩුව', 'ආණ්ඩුව'), ('ආ්ණඩුව', 'ආණ්ඩුව'), ('විහිුළවට', 'විහිළුවට')]
#   Corrected Sentence: පළවෙනිම ද තමය ම ආණ්ඩුව පත්වෙච්ච තැන ඉදල පේන්න ආණ්ඩුව විහිළුවට ලක්වෙනව න
#
# Sentence 51:
#   Spelling Mistakes and Corrections: [('බර', 'බ')]
#   Corrected Sentence: එකක තමය ආණ්ඩුව බ
#
# Sentence 52:
#   Spelling Mistakes and Corrections: [('නජාධිපතිවරායග', 'ජනාධිපතිවරායග'), ('කඑ', 'කඩ'), ('අනර', 'අනුර')]
#   Corrected Sentence: ජනාධිපතිවරායග ඉදල බොර කියනව කියන කඩ සමාජ ගත වෙන්න පටන අනුර තියෙනව
#
# Sentence 53:
#   Spelling Mistakes and Corrections: [('දන', 'ඕන'), ('ඔක්කම', 'ඔක්කොම'), ('කිලය', 'කාලය')]
#   Corrected Sentence: ඕන ලිස්ට එකක එනව අරයාග උපාධිය මෙයාග මහාචාර්යකම ඔක්කොම බොර කාලය
#
# Sentence 54:
#   Spelling Mistakes and Corrections: [('ගබොෙල්ස', 'ගොබෙල්ස')]
#   Corrected Sentence: ඕක ගොබෙල්ස තියර එක වෙන්නත පුළුවන
#
# Sentence 55:
#   Spelling Mistakes and Corrections: [('නැත්න්ම', 'නැත්නම')]
#   Corrected Sentence: එහෙම නැත්නම ඇත්ත වෙන්නත පුළුවන
#
# Sentence 56:
#   Spelling Mistakes and Corrections: [('පරතිරූපයට', 'ප්රතිරූපයට'), ('හනාියක', 'හානියක')]
#   Corrected Sentence: ඕක සමාජ ගතවුණොත ආණ්ඩුව ප්රතිරූපයට ලොක හානියක
#
# Sentence 57:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: මහාචාර්යවරය කිය සිටියේය
#
# Sentence 58:
#   Spelling Mistakes and Corrections: [('වනොව', 'වෙනව')]
#   Corrected Sentence: මිනිස්ස දැන ලින්කින්ඩ ප්රොෆයිල වලින අයින වෙනව
#
# Sentence 59:
#   Spelling Mistakes and Corrections: [('වෙන්ස', 'වෙන්න')]
#   Corrected Sentence: වෙබ සයිට්වල නම වෙන්න කරනව
#
# Sentence 60:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: රජයක ජොක්වුණාම
#
# Sentence 61:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: විහිළුවට ලක්වුණ ම හරිම නරකය
#
# Sentence 62:
#   Spelling Mistakes and Corrections: [('රනි්ල', 'රනිල')]
#   Corrected Sentence: රනිල වික්රමසිංහ වුණත වෙනකම ලොක ප්රතිරූපයක
#
# Sentence 63:
#   Spelling Mistakes and Corrections: [('දිසනාායකල', 'දිසානායකල'), ('කෙෙනක', 'කෙනෙක')]
#   Corrected Sentence: ගාමිණ දිසානායකල ලලිත ඇතුලත්මුදලිල එක්ක සමකාලීනව හිටප කෙනෙක
#
# Sentence 64:
#   Spelling Mistakes and Corrections: [('මසරවීරලාග', 'සමරවීරලාග'), ('එාය', 'එය')]
#   Corrected Sentence: හැබැය එයාව මිස්ටර බීන ට සම්බන්ධ කලාට පස්ස න පස්ස මංගල සමරවීරලාග ව්යාපෘතියත එක්ක එය ජොක එකක වුණාන
#
# Sentence 65:
#   Spelling Mistakes and Corrections: [('පසස', 'පහස'), ('පේනන', 'පෙන්න'), ('තඅ', 'තබ')]
#   Corrected Sentence: ඊට පහස මිනිස්සුන්ට පෙන්න එය කත කළත ජෝක තබ ඉස්සුවත ජොක
#
# Sentence 66:
#   Spelling Mistakes and Corrections: [('හැබැිය', 'හැබැය'), ('පණර', 'පෙර')]
#   Corrected Sentence: හැබැය ඒ පෙර හිටප රනිල වික්රමසිංහම තමය
#
# Sentence 67:
#   Spelling Mistakes and Corrections: [('ටර', 'හර'), ('කිය්නන', 'කියන'), ('බර', 'බ'), ('පාර්ලිමනේ්තුව', 'පාර්ලිමේන්තුව'), ('ජනාිධපතිවරය', 'ජනාධිපතිවරය')]
#   Corrected Sentence: හර නායකය කියන බ කියල ඒක සමාජ ගතවුණොත මිනිස්සුන්ට රජය ගැන පාර්ලිමේන්තුව ගැන ජනාධිපතිවරය ගැන තියෙන ප්රතිරූපය හර සෘණාත්මකය
#
# Sentence 68:
#   Spelling Mistakes and Corrections: [('කඒ', 'කඩ'), ('විිහළුවට', 'විහිළුවට')]
#   Corrected Sentence: කඩ විහිළුවට එහ ගියප දේශපාලන පරිහානියක එන්න පුළුවන
#
# Sentence 69:
#   Spelling Mistakes and Corrections: [('විශ්වාසභංයග', 'විශ්වාසභංග'), ('කරන්ේන', 'කරන්න')]
#   Corrected Sentence: ක ඉන්න තැනක විශ්වාසභංග අත්සන කරන්න සුළ පිරිසක
#
# Sentence 70:
#   Spelling Mistakes and Corrections: [('සට්ෙපඩ්වුන', 'ස්ටෙප්ඩවුන'), ('වුාණ', 'වුණ')]
#   Corrected Sentence: විශ්වාසභංගය අත්සන කරන කොට ම අයට ස්ටෙප්ඩවුන කරන්න සිද්ධ වුණ
#
# Sentence 71:
#   Spelling Mistakes and Corrections: [('ස්ටෙප්ඩවන', 'ස්ටෙප්ඩවුන'), ('ගොකඩ', 'ලොක'), ('ගැවලෙනව', 'ගැලවෙනව')]
#   Corrected Sentence: ස්ටෙප්ඩවුන වුණ පාර්ලිමේන්තුව ම විවාදය ගිය නම ලොක අයග රෙද ගැලවෙනව
#
# Sentence 72:
#   Spelling Mistakes and Corrections: [('සප්ස', 'ඔස්ස'), ('පට්නගන්නව', 'පටන්ගන්නව')]
#   Corrected Sentence: ඊට ඔස්ස වත්කම ගැන පුද්ගලයින ගැන හොයන්න පටන්ගන්නව
#
# Sentence 73:
#   Spelling Mistakes and Corrections: [('බර', 'බ'), ('කාරෝය', 'කාරය'), ('තග', 'තබ'), ('නත', 'ගත')]
#   Corrected Sentence: බ කාරය කියන එක සමාජ තබ වුණොත ආණ්ඩුව ගැන තියෙන ප්රසාදය සහ විශ්වාසය ගත වෙනව
#
# Sentence 74:
#   Spelling Mistakes and Corrections: [('කඑ්ක', 'එක්ක'), ('තළ', 'තුළ'), ('ජෝක', 'ජොක')]
#   Corrected Sentence: පහුගිය කාල සජිත ප්රේමදාස කියපුව එක්ක සමාජ මාධ්ය තුළ වැඩිපුරම සර්ච කරල තිබ්බ සජිත ජොක කියන එක න
#
# Sentence 75:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: පොසිටිව නෙම
#
# Sentence 76:
#   Spelling Mistakes and Corrections: [('සිජත', 'සිද')]
#   Corrected Sentence: සිද ජෝක්ස කියන එක
#
# Sentence 77:
#   Spelling Mistakes and Corrections: [('තිෙනයව', 'තිබෙනව')]
#   Corrected Sentence: සජිත ප්රේමදාසග නායකත්වය දැන අර්බුදයට ලක්වෙල තිබෙනව
#
# Sentence 78:
#   Spelling Mistakes and Corrections: [('රනි්ල', 'රනිල')]
#   Corrected Sentence: රනිල වික්රමසිංහටත ඒ ද වුණ
#
# Sentence 79:
#   Spelling Mistakes and Corrections: [('පුළුනව', 'පුළුවන')]
#   Corrected Sentence: ම ආණ්ඩුවටත එහෙම වෙන්න පුළුවන
#
# Sentence 80:
#   Spelling Mistakes and Corrections: [('පැවසය', 'පැවසීය')]
#   Corrected Sentence: මහාචාර්ය අමින්ද මෙත්සිල පෙරේර වැඩිදුරටත පැවසීය
#
# Sentence 81:
#   Spelling Mistakes and Corrections: [('පන්ව', 'පෙන්ව'), ('අව්සථාවේද', 'අවස්ථාවේද'), ('ආණඩු්වට', 'ආණ්ඩුවට')]
#   Corrected Sentence: ර ජයවර්ධනපුර විශ්වවිද්යාලය දේශපාලන විද්ය අධ්යයන අංශය මහාචාර්ය විශාක සූරියබණ්ඩාර පෙන්ව දුන්න ම අවස්ථාවේද ආණ්ඩුවට ස්වය විවේචනයක අවශ්ය බවය
#
# Sentence 82:
#   Spelling Mistakes and Corrections: [('ආණඩ්ුවෙන', 'ආණ්ඩුවෙන')]
#   Corrected Sentence: මිනිස්ස ම ආණ්ඩුවෙන ඉල්ලන්න අවංකකම
#
# Sentence 83:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: පළවෙන ද
#
# Sentence 84:
#   Spelling Mistakes and Corrections: [('රවටුණ', 'රැවටුණ')]
#   Corrected Sentence: මිනිස්සුන්ට ඕන අප රැවටුණ නැහ කියල හිතන ඒ සිතුවිල්ල ඔළුවට දාගන්න
#
# Sentence 85:
#   Spelling Mistakes and Corrections: [('ඩඉක', 'ලොක'), ('පක්යෂක', 'පක්ෂයක')]
#   Corrected Sentence: ඒකට ලොක තියෙනව නම හොඳය කියන එක තම මම නම හිතන්න පක්ෂයක විදිහට
#
# Sentence 86:
#   Spelling Mistakes and Corrections: [('පකෂ', 'පක්ෂ'), ('කයිල', 'අයින'), ('හතිාගෙන', 'හිතාගෙන')]
#   Corrected Sentence: සාම්ප්රදායීක දේශපාලන පක්ෂ එප අයින ම ඡන්දෙද ජනතාව ම ගොල්ලන්ට ඡන්දය දුන්න පිරිසිද දේශපාලනය හිතාගෙන
#
# Sentence 87:
#   Spelling Mistakes and Corrections: [('හිතුේව', 'හිතුව'), ('කඑ', 'කඩ')]
#   Corrected Sentence: මිනිස්ස ඇත්තටම හිතුව පිරිසිද බව කියන කඩ
#
# Sentence 88:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ඒක නැතිවුණාම නික විවාහයට වුණත එවග දෙයක නැතිවුණාම
#
# Sentence 89:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: අප ලංකාව සංස්කෘතිය හරිම බලවත න පියොරිට කියන එක
#
# Sentence 90:
#   Spelling Mistakes and Corrections: [('කඒ', 'කඩ'), ('කාඩ', 'කඩ')]
#   Corrected Sentence: කඩ නැතිවුණාම මිනිස්ස හරියට කඩ වැටෙනව න
#
# Sentence 91:
#   Spelling Mistakes and Corrections: [('මක', 'මහ'), ('වේග', 'වග')]
#   Corrected Sentence: මහ හරියට අර පවුල සංස්ථාවකට වුණ වග වැඩක න
#
# Sentence 92:
#   Spelling Mistakes and Corrections: [('කඒ', 'කඩ'), ('නස', 'අස'), ('ව්ායකූල', 'ව්යාකූල')]
#   Corrected Sentence: කඩ අස මිනිස්සුන්ග දැන එක පැත්තකින මනස ව්යාකූල වෙල තියෙනව ම තත්ත්වය පිළිබඳව
#
# Sentence 93:
#   Spelling Mistakes and Corrections: [('මිනිසස', 'මිනිස්ස'), ('ගඩොක', 'ලොක'), ('මකොද', 'මොකද')]
#   Corrected Sentence: මිනිස්ස ලොක අය කත කරන්න නැතිව බලාගෙන ඉන්නව මොකද වෙන්න කියල
#
# Sentence 94:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: මහාචාර්යවරිය පෙන්ව දුන්නාය
#
# Sentence 95:
#   Spelling Mistakes and Corrections: [('කතානායකවයරාග', 'කතානායකවරයාග'), ('ආන්දලෝනයට', 'ආන්දෝලනයට'), ('දම', 'දෙම'), ('ප්රකාකශ', 'ප්රකාශ'), ('වද්ය', 'විද්ය'), ('ජයිතස්සගෙන', 'ජයතිස්සගෙන'), ('විමාස', 'විමස')]
#   Corrected Sentence: කතානායකවරයාග ආන්දෝලනයට තුඩ ද ඇත ආචාර්ය උපාධිය සම්බන්ධයෙන දෙසැම්බර වැන ද ඔහුග ඉල්ල අස්වීම තීරණය ප්රකාශයට පත කිරීමට පෙර පැවත කැබිනට තීරණ දැණුම දෙම ප්රවෘත්ත සාකච්ඡාවේද මාධ්යවේදීන කැබිනට ප්රකාශ අමාත්ය විද්ය නලින්ද ජයතිස්සගෙන විමස සිටිය ය
#
# Sentence 96:
#   Spelling Mistakes and Corrections: [('වෛ්දය', 'ඡන්දය'), ('සම්බන්ධයේන', 'සම්බන්ධයෙන'), ('ප්රකාශකය', 'ප්රකාශක'), ('වත', 'වට'), ('දන', 'ඕන')]
#   Corrected Sentence: එහිද කැබිනට ප්රකාශක අමාත්ය ඡන්දය නලින්ද ජයතිස්ස කිය සිටිය කතානායකවරය ම සම්බන්ධයෙන ඉත ම පැහැදිල ප්රකාශක වට ඕන කිහිපයකින සිදුකරාව
#
# Sentence 97:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: බලාගෙන ඉන්න
#
# Sentence 98:
#   Spelling Mistakes and Corrections: [('මස්බන්ධයෙන', 'සම්බන්ධයෙන'), ('ඉාත', 'ඉත')]
#   Corrected Sentence: ඒ සම්බන්ධයෙන අප ඉත වගකීම්සහගත ප්රකාශයක කතානායකවරයාග පැත්තෙන සිද්ධ කරාව
#
# Sentence 99:
#   Spelling Mistakes and Corrections: [('පළිිබඳ', 'පිළිබඳ')]
#   Corrected Sentence: කතානායකවරය තමන්ග සුදුසුකම පිළිබඳ වාර්ත කරහ ම බලම යනුවෙන
#
# Sentence 100:
#   Spelling Mistakes and Corrections: [('ජනධාිපත', 'ජනාධිපත'), ('දසනාායක', 'දිසානායක'), ('කනර', 'කවර'), ('කිසවෙික', 'කිසිවෙක'), ('කිීරමට', 'කිරීමට'), ('සදූානම', 'සූදානම')]
#   Corrected Sentence: දෙසැම්බර වන ද රජය මාධ්ය ප්රධානීන සමග පැවත සාකච්ඡාවක ද ජනාධිපත අනුර කුමාර දිසානායක අවධාරණය කට තිබුණ රට තුළ වැරද කවර කිසිවෙක කිසිම හේතුවකට ආරක්ෂ කිරීමට අප ආණ්ඩුව සූදානම නැහ
#
# Sentence 101:
#   Spelling Mistakes and Corrections: [('තළ', 'තුළ'), ('ආණ්ඩව', 'ආණ්ඩුව'), ('න්ම', 'නම'), ('ක්රියමාාර්ග', 'ක්රියාමාර්ග')]
#   Corrected Sentence: රට තුළ පමණක නෙවෙය අප ආණ්ඩුව තුළ කවර තරාතිරමක කෙනෙක වුණත වැරැද්දක කරනව නම ඒ වැරැද්දට එරෙහිව ක්රියාමාර්ග ගන්න අප පැකිළෙන්න නැහ
#
# Sentence 102:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: යනුවෙන
#
# Sentence 103:
#   Spelling Mistakes and Corrections: [('වරැටීමට', 'රැවටීමට'), ('තිබන', 'තිබ'), ('සුර්කෂිත', 'සුරක්ෂිත'), ('කනෝදේස', 'කොන්දේස'), ('වබ', 'බ'), ('වැඩිදුරතට', 'වැඩිදුරටත'), ('කය', 'අය')]
#   Corrected Sentence: දශක ක තිස්ස රැවටීමට කල ව ජනතාව තමන කෙරෙහ තබ තිබ විශ්වාසය සුරක්ෂිත කිරීමට සහ රට වඩ යහපත රටක කිරීමට තම රජය කොන්දේස විරහිතව කැප වෙන බ ද ජනාධිපතිවරය එහිද වැඩිදුරටත අය සිටියේය
#
# Sentence 104:
#   Spelling Mistakes and Corrections: [('මොොහතක', 'මොහොතක'), ('ගනැීම', 'ගැනීම'), ('වනාශකාර', 'විනාශකාර'), ('බලපම', 'බලම')]
#   Corrected Sentence: ඕනෑම මොහොතක ඇතිවිය හැක ගින ගැනීම හේතුවෙන ඔබට හ ඔබ සිටින ස්ථානවලට ඉත විනාශකාර බලම එල්ල විය හැකිය
#
# Sentence 105:
#   Spelling Mistakes and Corrections: [('ගැනම', 'ගැන'), ('නවිීම', 'වීම'), ('පැසවුව', 'පැවසුව'), ('සීාමව', 'සීමාව'), ('කොඹළ', 'කොටස'), ('ටවඅ', 'ආවම'), ('පර්දේශවල', 'ප්රදේශවල'), ('ගැීනම', 'නැතනම'), ('තඇ', 'තබ')]
#   Corrected Sentence: එවැන ගින ගැන සහ ඒ ආශ්රිත අනතුර සම්බන්ධයෙන බීබීස සිංහල සේවය කළ විමසීමකද කොළඹ ගින වීම ඒකකය පැවසුව වසර ම දක්ව කාල සීමාව තුලද කොටස නගරය සහ ආවම ප්රදේශවල පමණක ගින නැතනම සිදුවීම ක වාර්තාව තබ බවය
#
# Sentence 106:
#   Spelling Mistakes and Corrections: [('විශේයෂෙන', 'විශේෂයෙන'), ('පදු්ගලයෙක', 'පුද්ගලයෙක'), ('අවසථ්ාවකද', 'අවස්ථාවකද'), ('මොවනාද', 'මොනවාද'), ('ය්නන', 'යන්න'), ('දැනවුත්වීම', 'දැනුවත්වීම'), ('වදැගත', 'වැදගත')]
#   Corrected Sentence: හදිස ගින්නක හට ගත අවස්ථාවකද අප සිදුකළ යුත්ත කුමක්ද විශේෂයෙන මහල ගොඩනැගිල්ලක සිටින පුද්ගලයෙක මෙවැන අවස්ථාවකද ගත යුත ක්රියාමාර්ග මොනවාද යන්න කල තිය දැනුවත්වීම ඉත වැදගත ය
#
# Sentence 107:
#   Spelling Mistakes and Corrections: [('සිදුළක', 'සිදුකර'), ('තත්්තවය', 'තත්ත්වය'), ('අවනශ්ය', 'අවශ්ය'), ('ලස', 'ලෙස'), ('ගොඩනැගලි්ලෙන', 'ගොඩනැගිල්ලෙන'), ('ආරක්ාෂ', 'ආරක්ෂ'), ('ඉජංිනේර', 'ඉංජිනේර'), ('ලේමක', 'ලොක'), ('නලක', 'නාලක'), ('සංිහල', 'සිංහල'), ('වත', 'වට')]
#   Corrected Sentence: හදිස ගින්නක ඇතිව වට ඕනෑම පුද්ගලයෙක සිදුකර යුත්ත ඇතිව තිබෙන තත්ත්වය තේරුම්ගෙන අවශ්ය ලෙස කලබල විමෙන වැළක තමන්ට ලබාද ඇත උපදෙස අනුව ගොඩනැගිල්ලෙන ආරක්ෂ සහිතව ඉවත්වීම මාර්ගයට ඇතුල්වීම බව බ්රිතාන්ය ගින ඉංජිනේර සංගමය ශ්ර ලක ශාඛාව ලොක නාලක ජයරත්න බීබීස සිංහල සේවය වට අදහස දක්වමින පැවසුවේය
#
# Sentence 108:
#   Spelling Mistakes and Corrections: [('නඕ', 'නම'), ('කලලබයට', 'කලබලයට'), ('ගන', 'ඕන')]
#   Corrected Sentence: අප නම තරම දැකල තියෙනව ගින්නකද මිනිස්ස කලබලයට පත්වන අවස්ථාවන ඕන
#
# Sentence 109:
#   Spelling Mistakes and Corrections: [('හඑෙම', 'එහෙම'), ('කලබලෙවල', 'කලබලවෙල'), ('ඇතුටල', 'ඇතුලට'), ('කයල', 'කාල')]
#   Corrected Sentence: එහෙම කලබලවෙල බය වෙල ගොඩක වෙලාවට බාත්රූම ඇතුලට ගිහිල්ල රැඳ ඉන්නව එතන වතුර තියෙනවන කාල
#
# Sentence 110:
#   Spelling Mistakes and Corrections: [('නඉ්න', 'නොවන'), ('මයිගිය', 'මියගිය')]
#   Corrected Sentence: නමුත එහෙම නොවන අය මියගිය අවස්ථාවන වාර්ත වෙනව
#
# Sentence 111:
#   Spelling Mistakes and Corrections: [('නග්න', 'නොවන'), ('එහෙතම', 'එහෙම'), ('දම', 'දෙම'), ('ආඝ්ණයර', 'ආඝ්රණය')]
#   Corrected Sentence: වතුර තිබුනට ජිවිත හාන වෙන්න ඇතිවෙන ගින්න නිස හුස්ම නොවන අවශ්ය ඔක්සිජන නැතුව එහෙම නැතනම දෙම ආඝ්රණය වීම නිස
#
# Sentence 112:
#   Spelling Mistakes and Corrections: [('වගේයම', 'වගේම'), ('අපහසුවෙවන', 'අපහසුවෙනව')]
#   Corrected Sentence: ඒ වගේම ම වග අවස්ථාවලද ගලව ගැනීම ක්රියාවලිය සිදුකරන්න අපහසුවෙනව
#
# Sentence 113:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ඔහ පැවසුවේය
#
# Sentence 114:
#   Spelling Mistakes and Corrections: [('ගොඩනැගිලල්ක', 'ගොඩනැගිල්ලක'), ('ගිින', 'ගින'), ('ක්රිාය', 'ක්රිය'), ('ළක', 'ඕක'), ('ටඊ', 'ට'), ('අශව්ය', 'අනවශ්ය'), ('පඋකරණ', 'උපකරණ'), ('නමොැත', 'නැත'), ('යමට', 'යම')]
#   Corrected Sentence: මහල ගොඩනැගිල්ලක තුළ අනිවාර්යෙන්ම හදිස ගින ගැනීමක හටගත අවස්ථාවකද ක්රිය ඕක යුත ආකාරය මෙන්ම ට අනවශ්ය උපකරණ තිබිය යුත බවත එවැන පියවර ගෙන නැත ගොඩනැගිල පවත්වාගෙන යම ඉඩ නොදෙන බවත නාලක ජයරත්න පැවසුවේය
#
# Sentence 115:
#   Spelling Mistakes and Corrections: [('ගොඩනැගලි්ලක', 'ගොඩනැගිල්ලක'), ('සව', 'ව'), ('නඅුව', 'අනුව'), ('කිිහපයක', 'කිහිපයක')]
#   Corrected Sentence: මහල ගොඩනැගිල්ලක ගත්තම ගින නිවීම ව දෙපාර්තමේන්තුව උපදෙස අනුව ගින ආරක්ෂණ පද්ධත කිහිපයක අඩංග වෙන්න ඕන
#
# Sentence 116:
#   Spelling Mistakes and Corrections: [('ජනතාටව', 'ජනතාව'), ('රඳ', 'රැඳ')]
#   Corrected Sentence: එහෙම නැතුව මහල ගොඩනැගිල්ලක ජනතාව රැඳ සිටින්න ඉඩදෙන්න නැහ
#
# Sentence 117:
#   Spelling Mistakes and Corrections: [('යත', 'ගත'), ('ලවන', 'ආවන'), ('සථ්ාන', 'ස්ථාන')]
#   Corrected Sentence: විශේෂයෙන්ම මහල ගොඩනැගිල්ලක තිබිය ගත ගින ගැනීම ආවන ආරක්ෂාවීම ස්ථාන සහ උපකරණ කිහිපයක්ම තියෙනව
#
# Sentence 118:
#   Spelling Mistakes and Corrections: [('පරූ්ව', 'පූර්ව'), ('කිරම', 'කරම'), ('ආරකෂ', 'ආරක්ෂ'), ('හක', 'හර'), ('පිිරසට', 'පිරිසට'), ('තබිිය', 'තිබිය'), ('යුුතය', 'යුත')]
#   Corrected Sentence: පූර්ව ගින අනතුර සංඥාවන නිකුත කරම පද්ධතියක වගේම ගින නිවීම දියර ගින්නෙන සහ දුමෙන ආරක්ෂ විය හර කුට ගොඩනැගිල්ල වෙසෙන පිරිසට ආරක්ෂාකාර ලෙස ඉවත්ව යන තෙක එකතුවිය හැක ස්ථානයක ම මහල ගොඩනැගිල්ලක තිබිය යුත
#
# Sentence 119:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ඔහ පැවසුවේය
#
# Sentence 120:
#   Spelling Mistakes and Corrections: [('ගිනන්ක', 'ගින්නක'), ('ඉ්න', 'ඉන්න'), ('පටිවීම', 'පිටවීම'), ('ලැබන', 'ලැබ')]
#   Corrected Sentence: මහල ගොඩනැගිල්ලක ගින්නක ඇතිව විට ඉන්න පිටවීම සඳහ ලැබ කාලය ගැන ද මෙහිද නාලක ජයරත්න පැහැදිළ කළේය
#
# Sentence 121:
#   Spelling Mistakes and Corrections: [('ගන', 'ඕන'), ('හඳුනාගැනම', 'හඳුනාගැනීම'), ('නකිු්ත', 'නිකුත')]
#   Corrected Sentence: මහල ගොඩනැගිල්ලක ගින්නක හට ගත්තොත ඕන ගැනීම හඳුනාගැනීම උපකරණ එය හඳුනාගෙන අනතුර ඇඟවීම සංඥාවන නිකුත කරනව
#
# Sentence 122:
#   Spelling Mistakes and Corrections: [('දැකක', 'දැකල'), ('ගනීැම', 'ගැනීම'), ('නඅතුර', 'අනුර')]
#   Corrected Sentence: එහෙම නැත්නම ගින්න දැකල කෙනෙක ගින ගැනීම පිළිබඳව අනුර ඇඟවීම සංඥාව නාද කරන්න පුළුවන
#
# Sentence 123:
#   Spelling Mistakes and Corrections: [('එෙහම', 'එහෙම'), ('කරපුමව', 'කරපුවම'), ('සටින', 'සිටින'), ('පුද්ගලියන', 'පුද්ගලයින')]
#   Corrected Sentence: එහෙම අනතුර ඇඟවීම ඇක්ටිව කරපුවම මහල ගොඩනැගිලිවල සිටින පුද්ගලයින ඉවත කිරීම සිදුකරන්න ක්රමවේදයකට අනුවය
#
# Sentence 124:
#   Spelling Mistakes and Corrections: [('ටහගත', 'ගත'), ('කරනන', 'කරන්න'), ('දහිස', 'දින'), ('ගලාව', 'ගලව'), ('භවත', 'බවත')]
#   Corrected Sentence: ගින්න ගත මහල නිවාසය ඉන්න සියලුම දෙන එකවර ඉවත කරන්න ගියොත දින ගලව ගැනීම සඳහ බවත කරන තරප්ප පේළිය අවහිර වෙන්න පුළුවන
#
# Sentence 125:
#   Spelling Mistakes and Corrections: [('මිනි්තත', 'මිනිත්ත'), ('කාලය්ක', 'කාලයක'), ('තිෙයනව', 'කියනව')]
#   Corrected Sentence: සාමාන්යයෙන තට්ට නිවාසයක ගින්නක ඇතිවුණාම එතනින ආරක්ෂ සහිතව පිටතට යන්න ලැබෙන කාලය මිනිත්ත ක මිනිත්ත ය තත්පර ක වග කාලයක කියනව
#
# Sentence 126:
#   Spelling Mistakes and Corrections: [('නස', 'අස'), ('පුද්ගයලෙකුට', 'පුද්ගලයෙකුට'), ('ගැනමීක', 'ගැනීමක'), ('ඟඅවන', 'නොවන'), ('ගම්න', 'ගන්න'), ('තයෙන', 'තියෙන'), ('ගැනී්ම', 'ගැනීම'), ('කොසට', 'කොට'), ('දහල', 'දීල'), ('පිටවේනන', 'පිටවෙන්න'), ('කරිීම', 'කරම')]
#   Corrected Sentence: ම අස ගොඩනැගිල්ලක සිටින පුද්ගලයෙකුට ගින ගැනීමක ගැන අනතුර නොවන සංඥාවක ඇසුණ ගන්න අනිවාර්යෙන්ම ළඟම තියෙන හදිස පිටවීම දොරටුව භාවිත කරල ඒක තියෙන ගින ගැනීම වලින ආරක්ෂ වන කොට ඔස්ස දීල තියෙන තරප්ප පේලිය ඔස්ස ඉන පිටවෙන්න කටයුත කරම වැදගත
#
# Sentence 127:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: අප ම වග ස්ථානයන්ට කියන්න ප්රොටෙක්ටර්ඩ ෂාෆ්ටර කියල
#
# Sentence 128:
#   Spelling Mistakes and Corrections: [('අමව', 'අයව'), ('යකනම', 'යනව'), ('ගැටලවුක', 'ගැටලුවක')]
#   Corrected Sentence: ම වග ස්ථානයකට අයව වශයෙන පැය ක වග කාලයක යනව ගින්නෙන හ දුමෙන කිසිම ගැටලුවක ඇතිවෙන්න නැහ
#
# Sentence 129:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ඔහ පැවසුවේය
#
# Sentence 130:
#   Spelling Mistakes and Corrections: [('මහ්ල', 'මහල'), ('බආාධ', 'ආබාධ'), ('තත්ත්යව', 'තත්ත්වය'), ('අවධනාය', 'අවධානය'), ('දවැගත', 'වැදගත'), ('පැවුසවේය', 'පැවසුවේය')]
#   Corrected Sentence: මහල ගොඩනැගිලිවල සිටින ඇවිද ගැනීමට අපහස සහ විවිධ ආබාධ තත්ත්වය පසුවන පුද්ගලයින පිළිබඳව ද විශේෂයෙන අවධානය යොම කිරීම වැදගත බව ද ඔහ මෙහිද පැවසුවේය
#
# Sentence 131:
#   Spelling Mistakes and Corrections: [('ඇිවද', 'සිද'), ('වෙනන', 'වෙන'), ('ම්ටටම', 'මට්ටම'), ('ආර්කෂ', 'ආරක්ෂ'), ('සිදුරකන', 'සිදුකර'), ('ස්ාථන', 'ස්ථාන'), ('න්ම', 'නම')]
#   Corrected Sentence: සමහර ගොඩනැගිලිවල සිද ගන්න බැරිව හස හදිසිය ඉවත වෙන අපහස මට්ටම අයට ආරක්ෂ සහිතව ඉවත කර ගැනීම කටයුත සිදුකර තෙක ආරක්ෂ සහිතව රැඳ ඉන්න ස්ථාන නම කර තිබෙනව
#
# Sentence 132:
#   Spelling Mistakes and Corrections: [('සවකයින්ගෙන', 'සේවකයින්ගෙන'), ('පණම', 'සෑම'), ('රකන්න', 'යන්න'), ('හැටිටය', 'හැටියට')]
#   Corrected Sentence: අප සාමාන්යයෙන උපදෙස දෙනව කාර්යාලයක ඉන්න සේවකයින්ගෙන සීයයට ක සෑම පිරිසක පුහුණ යන්න කියල බඩීස්ල සහයකයින හැටියට
#
# Sentence 133:
#   Spelling Mistakes and Corrections: [('මතය', 'මත'), ('ඇවිගදන්න', 'ඇවිදගන්න'), ('අපහුස', 'අපහස'), ('යඅ', 'යම')]
#   Corrected Sentence: එහෙම අය මත කාර්යාලයක ඉන්න ඇවිදගන්න අපහස අය ඒ වගේම ආබාධිත යම ඉන්නව නම ගින්නකද ගොඩනැගිල්ලෙන ආරක්ෂ සහිතව පිටතට යන්න උපකාර කරන්න
#
# Sentence 134:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ඔහ පැවසුවේය
#
# Sentence 135:
#   Spelling Mistakes and Corrections: [('ගින්න්ක', 'ගින්නක'), ('අමරත', 'අමතර'), ('වගලාබ', 'වගබල'), ('බරිතාන්ය', 'බ්රිතාන්ය'), ('සංගයම', 'සංගමය'), ('ශ්ීර', 'ශ්ර')]
#   Corrected Sentence: ම අතර ගින්නක ඇතිව වට ඒ පිළිබඳව අමතර විස්තර සෙවීම පසෙකල ගොඩනැගිල්ලෙන ඉවත වීමට කටයුත කිරීම සිදුකිරිමට වගබල ගත යුත බව ද බ්රිතාන්ය ගින ඉංජිනේර සංගමය ශ්ර ලංක ශාඛාව ලේකම නාලක ජයරත්න පැවසුවේය
#
# Sentence 136:
#   Spelling Mistakes and Corrections: [('බොුර', 'බොර'), ('කිනය', 'කිය'), ('ඟළම', 'සෑම'), ('තිෙනය', 'තිබිය'), ('ස්ථානෙයන', 'ස්ථානයට')]
#   Corrected Sentence: වැදගත්ම ද තමය මේක ඇත්ත ගින්නක ද බොර ගින්නක ද කිය එක ගැන විස්තර හොයන්න නැතිව සෑම තිබිය ස්ථානයට පිටවෙන්න කටයුත කරන්න
#
# Sentence 137:
#   Spelling Mistakes and Corrections: [('රනක්න', 'යන්න')]
#   Corrected Sentence: ඒ වගේමය මොනම විදිහකටවත විදුල සෝපාන පාවිච්ච යන්න එප
#
# Sentence 138:
#   Spelling Mistakes and Corrections: [('සෝපන', 'සෝපාන'), ('හදිිස', 'හදිස'), ('ස්වයංකර්ීයව', 'ස්වයංක්රීයව')]
#   Corrected Sentence: බොහ ගොඩනැගිලිවල තියෙන විදුල සෝපාන හදිස ගින්නකද ස්වයංක්රීයව නතර වෙනව
#
# Sentence 139:
#   Spelling Mistakes and Corrections: [('කර්නන', 'කරන්න'), ('පුළු්වන', 'පුළුවන'), ('ඇතැ්ම', 'ඇතැම')]
#   Corrected Sentence: ඒ වගේම ගින ගැනීම වලද භාවිත කරන්න පුළුවන විශේෂ විදුල සෝපාන ඇතැම ගොඩනැගිලිවල තියෙනව
#
# Sentence 140:
#   Spelling Mistakes and Corrections: [('වේග', 'වග'), ('තෙයනව', 'වෙනව'), ('කයිල', 'අයින')]
#   Corrected Sentence: ඒ වග විදුල සෝපාන වල නම කර වෙනව ඒව හදිස ආපදාවලද භාවිත කරන්න පුළුවන අයින
#
# Sentence 141:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ඔහ පැවසුවේය
#
# Sentence 142:
#   Spelling Mistakes and Corrections: [('කාර්ායලවල', 'කාර්යාලවල'), ('ගැනීමේීද', 'ගැනීමේද'), ('පිවට', 'පියවර'), ('යත', 'ගත'), ('අවෝබධයක', 'අවබෝධයක'), ('බලාදීම', 'ලබාදීම'), ('සම', 'සෑම'), ('සිදුකරිීම', 'සිදුකිරීම'), ('යජරත්න', 'ජයරත්න')]
#   Corrected Sentence: මහල ගොඩනැගිලිවල පවත්වාගෙන යන ලබන කාර්යාලවල සේවය කරන පුද්ගලයින්ට ගින ගැනීමේද ආරක්ෂ සහිතව පියවර ය ගත ස්ථාන ගැන අවබෝධයක ලබාදීම හස සෑම වසරකම පුහුණුවීමක සිදුකිරීම අනිවාර්ය බව ද බ්රිතාන්ය ගින ඉංජිනේර සංගමය ශ්ර ලක ශාඛාව ලේකම නාලක ජයරත්න පැහැදිල කළේය
#
# Sentence 143:
#   Spelling Mistakes and Corrections: [('සේයවට', 'සේවය'), ('හඳුන්ාවදීම', 'හඳුන්වාදීම'), ('ගින්කනද', 'ගින්නකද'), ('ළක', 'ඕක'), ('ආකායර', 'ආකාරය'), ('පරූ්ව', 'පූර්ව'), ('ක්රිායත්මක', 'ක්රියාත්මක'), ('රකන', 'වෙන'), ('පටවීම', 'පිටවීම'), ('තියෙනන', 'තියෙන'), ('ස්ථනාය', 'ස්ථාන')]
#   Corrected Sentence: ම වග මහල ගොඩනැගිලිවල සේවය කරන පුද්ගලයෙක සේවය බඳව ගැනීමේද හඳුන්වාදීම වැඩසටහනේද ගින්නකද ක්රිය ඕක යුත ආකාරය ගින්නක දැක්කම ගින ගැනීම පූර්ව අනතුර ඇඟවීම සංඥ පද්ධතිය ක්රියාත්මක වෙන ආකාරය ආරක්ෂිත පිටවීම කොහෙද තියෙන ඒ වගේම ගොඩනැගිල්ලෙන ඉවත්වෙල රැඳ සිටිය යුත ස්ථාන කොහෙද තියෙන්න කියන එක ගැන දැනුවත කිරීම අනිවාර්යෙන්ම සිදුකල යුතුය
#
# Sentence 144:
#   Spelling Mistakes and Corrections: [('ගොඩැනගිල', 'ගොඩනැගිල'), ('සදිුකළ', 'සිදුකළ')]
#   Corrected Sentence: ඒ වගේම අවුරුද්දකට වරක ගින ගැනීමට අදාළ පෙරහුරුවන සිදුකිරීම මහල ගොඩනැගිල කළමනාකාරිත්වය විසින සිදුකළ යුතුය
#
# Sentence 145:
#   Spelling Mistakes and Corrections: [('අේප', 'අප'), ('නතිවුණත', 'නැතිවුණත'), ('ගොකඩ', 'ලොක'), ('රටලව', 'ගලව')]
#   Corrected Sentence: අප රට නැතිවුණත ලෝකය ලොක ගලව ම පෙරහුර සිදුකිරීම නීත මගින අනිවාර්ය කරල තියෙනව
#
# Sentence 146:
#   Spelling Mistakes and Corrections: [('අවස්ථානව', 'අවස්ථාව'), ('ළාඟ', 'ළඟ'), ('පළුුවන', 'පුළුවන'), ('නිරණ්ය', 'නිර්ණය')]
#   Corrected Sentence: ගින නිවීම නිලධාරීන්ට ගින ගැනීම අවස්ථාව වලද මහල ගොඩනැගිල්ලකද ළඟ වෙන්න පුළුවන උපරිම උස ප්රමාණය මීටර ක කියලය නිර්ණය කරල තියෙන්න
#
# Sentence 147:
#   Spelling Mistakes and Corrections: [('කාර්ය්ක', 'කාර්යක')]
#   Corrected Sentence: ඒක පහස කාර්යක නෙමෙය
#
# Sentence 148:
#   Spelling Mistakes and Corrections: [('විදහිට', 'විදිහට'), ('ත්ටටුව', 'තට්ටුව'), ('යඅ', 'යම')]
#   Corrected Sentence: උදාහරණයක විදිහට ගත්තම සාමාන්යයෙන වෙන තට්ටුව ගින්නක ඇතිවුණොත මුලින්ම ඉවත කරන්න ඒ තට්ටුව යම ඒ අය ඉවත කරල වෙන තට්ටුව අයව ඉවත කරනව
#
# Sentence 149:
#   Spelling Mistakes and Corrections: [('වේගම', 'වීම')]
#   Corrected Sentence: ඒ වීම ඊට පස්ස වෙන තට්ටුව ඉන්න පිරිස ඉවත කරනව
#
# Sentence 150:
#   Spelling Mistakes and Corrections: [('පානලය', 'පාලනය'), ('කයල', 'කාල'), ('නඉ්න', 'නොවන'), ('ඉතව', 'ඉත'), ('කටයුුත', 'කටයුත')]
#   Corrected Sentence: ඊට පස්ස ගින්න පාලනය කරන්න පුළුවන්ද කාල සොය බලලය අනෙක තට්ටුවල නොවන පිරිස ඉත කිරීමට කටයුත කරන්න
#
# Sentence 151:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ඔහ පැවසුවේය
#
# Sentence 152:
#   Spelling Mistakes and Corrections: [('ඇතිූව', 'ඇතිව'), ('මහ්ල', 'මහල'), ('පුදග්ලයෙකුට', 'පුද්ගලයෙකුට'), ('වවහොත', 'වුවහොත'), ('සංිහල', 'සිංහල'), ('විමීසමේද', 'විමසීමේද'), ('ශාඛාේව', 'ශාඛාව'), ('ලකේ්ම', 'ලක්ව'), ('නාකල', 'නාලක'), ('කළය', 'කළත')]
#   Corrected Sentence: ගින්නක ඇතිව අවස්ථාවකද මහල ගොඩනැගිල්ලකින එකවර පිටව යෑමට පුද්ගලයෙකුට නොහැක වුවහොත එහිද ගත යුත ක්රියාමාර්ග මොනවාදැය බීබීස සිංහල සේවය කළ විමසීමේද බ්රිතාන්ය ගින ඉංජිනේර සංගමය ශ්ර ලංක ශාඛාව ලක්ව නාලක ජයරත්න මෙලෙස එම ක්රියාවලිය පිළිබඳ පැහැදිළ කළත
#
# Sentence 153:
#   Spelling Mistakes and Corrections: [('ගන්නක', 'ගන්න'), ('ඇතිුවණ', 'ඇතිවුණ'), ('ම්ටටමකට', 'මට්ටමකට')]
#   Corrected Sentence: ගන්න ඇතිවුණ කියල එක පාරම ඒක විශාල මට්ටමකට එන්න නැහ
#
# Sentence 154:
#   Spelling Mistakes and Corrections: [('අිප', 'අප')]
#   Corrected Sentence: ඒකට අප කියන්න මට්ටම කියල
#
# Sentence 155:
#   Spelling Mistakes and Corrections: [('කයින', 'අයින'), ('ගි්නේන', 'ගින්නෙන'), ('ඇතවින', 'ඇවිත'), ('මිනි්තත', 'මිනිත්ත')]
#   Corrected Sentence: ඒ අයින මට්ටමට එනකම හ ගින්නෙන ඇවිත දුම බැරෑරුම මට්ටමට එන්න මිනිත්ත කට වඩ වැඩ කාලයක යනව
#
# Sentence 156:
#   Spelling Mistakes and Corrections: [('ලකය', 'ලෝකය')]
#   Corrected Sentence: ම ලෝකය කෙනෙක්ට ප්රමාණවත ආරක්ෂිත ස්ථානයකට යන්න
#
# Sentence 157:
#   Spelling Mistakes and Corrections: [('නයන', 'යන'), ('මාරග්ය', 'මාධ්ය'), ('අෙන්ක', 'වෙන්න'), ('පලිය', 'පේලිය')]
#   Corrected Sentence: එහෙම ආරක්ෂිත ස්ථානයකට යන තියෙන මාධ්ය ඇහිරිල තිබුණොත දෙවන පියවරක විදිහට වෙන්න තරප්ප පේලිය භාවිත කරන්න පුළුවන ගොඩනැගිල්ලෙන ඉවත වෙන්න
#
# Sentence 158:
#   Spelling Mistakes and Corrections: [('බැිරම', 'බැරිම'), ('ගොඩනැගි්ලලෙන', 'ගොඩනැගිල්ලෙන'), ('වෙනන', 'වෙන'), ('පුද්ගයලට', 'පුද්ගලයට')]
#   Corrected Sentence: නමුත බැරිම වෙලාවක ගොඩනැගිල්ලෙන ඉවත වෙන නැතිව හිටියොත ඒක ඉතාම බැරෑරුම වෙනව ඒ රැඳ ඉන්න පුද්ගලයට
#
# Sentence 159:
#   Spelling Mistakes and Corrections: [('විශේෂෙයන', 'විශේෂයෙන'), ('නලිධාරීන', 'නිලධාරීන'), ('බර', 'බ')]
#   Corrected Sentence: විශේෂයෙන එහෙම ඉන්න අයව ගින නිවීම නිලධාරීන ඇවිත බ ගන්නකම ඉන්න වෙනව
#
# Sentence 160:
#   Spelling Mistakes and Corrections: [('යඅ', 'යම'), ('හටිියොත', 'හිටියොත'), ('නිවීේම', 'නිවීම'), ('කරවන', 'කරන')]
#   Corrected Sentence: එහෙම යම හිටියොත ගින නිවීම නිලධාරීන මුද ගැනීම මෙහෙයුමක දියත කරන හිරවෙල ඉන්න අයව බේර ගන්න
#
# Sentence 161:
#   Spelling Mistakes and Corrections: [('හඑෙම', 'එහෙම'), ('දයක', 'දෙයක')]
#   Corrected Sentence: මේක ඉත අවාසනාවන්ත අපහසුතාවයක එහෙම දෙයක සිද්ධ වුණොත
#
# Sentence 162:
#   Spelling Mistakes and Corrections: [('වේනන', 'වෙන')]
#   Corrected Sentence: ඒ වගේමය ගොඩනැගිල්ලෙන පිටතට ආවම රැඳ සිටින ස්ථානයට ආවම එතැනින ඉවත වෙන එප
#
# Sentence 163:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: එතැනද සාමාන්යයෙන ෆයර රෙජිස්ටර එකක ගන්නව
#
# Sentence 164:
#   Spelling Mistakes and Corrections: [('ගොඩනගැිල්ල', 'ගොඩනැගිල්ල'), ('සිිටය', 'සිට'), ('ග්නන', 'ගන්න'), ('දන', 'ඕන'), ('නග්න', 'නොවන')]
#   Corrected Sentence: සේවකයින නැවත ගණනය කිරීමක කරනව ගොඩනැගිල්ල සිට පිරිස ආරක්ෂ සහිතව ඉවත්වුණ ද කියල හරියටම සැකහැර ගන්න ඕන නොවන
#
# Sentence 165:
#   Spelling Mistakes and Corrections: [('පහැදිල', 'පැහැදිල')]
#   Corrected Sentence: යනුවෙන ද ඔහ පැහැදිල කළේය
#
# Sentence 166:
#   Spelling Mistakes and Corrections: [('ලන්නඩ', 'යන්න'), ('කිාය', 'කිය'), ('සං්ඛයාව', 'සංඛ්යාව'), ('හැකියවාක', 'හැකියාව'), ('වබය', 'වූය')]
#   Corrected Sentence: නිවේදනයක නිකුත කරමින යන්න මෙට්රොපොලිටන පොලිසිය කිය සිටිය ඉදිරිය ද එම සංඛ්යාව වෙනසක සිද වීම හැකියාව පවතින වූය
#
# Sentence 167:
#   Spelling Mistakes and Corrections: [('කෙන්සනි්ටන', 'කෙන්සින්ටන'), ('වස', 'වට')]
#   Corrected Sentence: කෙන්සින්ටන ප්රදේශය පිහිට තට්ට වට හතරකින යුත ග්රෙන්ෆෙල මහල නිවාසය ජුන වෙනිද ගින්නට හස විය
#
# Sentence 168:
#   Spelling Mistakes and Corrections: [('ප්රතකිාර', 'ප්රතිකාර'), ('අසාධය', 'අසාධ්ය')]
#   Corrected Sentence: ගින්නට හස ව පුද්ගලයන්ගෙන දෙනෙක තවමත රෝහල ප්රතිකාර ලබන අතර ඉන දෙනෙක අසාධ්ය තත්වය පස වෙත
#
# Sentence 169:
#   Spelling Mistakes and Corrections: [('ගි්නනට', 'ගින්නට'), ('අනන්යාතව', 'අනන්යතාව'), ('වබ', 'බ'), ('පොලසිිය', 'පොලිසිය'), ('සහඳ', 'සහන'), ('කයර', 'ෆයර')]
#   Corrected Sentence: ගින්නට හසුව මරණයට පත ඇතමුන්ග අනන්යතාව හෙළ කර ගැනීමට අපොහොසත විය හැක බ පවසන ලන්ඩන පොලිසිය ඒ සහන සත ගණනාවක ගත වන ඇත බව සඳහන ෆයර
#
# Sentence 170:
#   Spelling Mistakes and Corrections: [('අරත', 'අත'), ('පයවර', 'පියවර'), ('වබට', 'වට'), ('අගමැිතනිය', 'අගමැතිනිය'), ('මට', 'වට'), ('ප්රාේදීශය', 'ප්රාදේශීය')]
#   Corrected Sentence: ම අත ගින්නෙන විපතට පත්වූවන්ට සහන සැලසීම සඳහ ප්රමාණවත පියවර ගැනීමට අපොහොසත ව ඇත වට බ්රිතාන්ය අගමැතිනිය තෙරේස වට සහ කෙන්සින්ටන ප්රාදේශීය බලධාරීන්ට චෝදන එල්ල ව
#
# Sentence 171:
#   Spelling Mistakes and Corrections: [('ව්යනසය', 'ව්යසනය'), ('මඑ', 'මහ'), ('ස්ථායන', 'ස්ථාන'), ('පත්ූවවන', 'පත්වූවන'), ('හසන', 'හස'), ('වත', 'වට'), ('පළිබඳ', 'පිළිබඳ'), ('අනතුටර', 'අනතුර'), ('පත්වව', 'පත්වූව')]
#   Corrected Sentence: ව්යසනය සිද වීමෙන පස මහ ස්ථාන වෙත ගිය අගමැතිනිය විපතට පත්වූවන මුණ නොගැස ගින නිවන භටයන සහ හස සේවකයන වට පමණක ගොස කරුණ විමසීම පිළිබඳ අනතුර පත්වූව විරෝධය පළ කළහ
#
# Sentence 172:
#   Spelling Mistakes and Corrections: [('අනතුරව', 'අනතුර'), ('ගස', 'ගොස'), ('කෙන්සිනට්න', 'කෙන්සින්ටන')]
#   Corrected Sentence: ඉන අනතුර විපතට පත්වූවන ගොස අගමැතිනිය අතර කෙන්සින්ටන දේවස්ථානය හමුවක පැවතිණ
#
# Sentence 173:
#   Spelling Mistakes and Corrections: [('හුමවෙන', 'හමුවෙන'), ('සට', 'වට'), ('නජතාව', 'ජනතාව'), ('ළප', 'ළඟ'), ('කහළ', 'කළ')]
#   Corrected Sentence: හමුවෙන අනතුරුව අගමැතිනිය එම ස්ථානයෙන පිටතට පැමිණ අවස්ථාව ඒ වට රැස්ව වට ජනතාව හ හඬ නගමින ඇය වෙත කෝපය ළඟ කළ

# %% [markdown]
# # Spell-Checker (DATASET2)

# %%
import pandas as pd
import re
import textdistance

def load_dataset():
    #load dataset
    dataset_path = "Dataset/dataset2.csv"
    data = pd.read_csv(dataset_path)
    print(data.head())
    return data

def tokenize_sentence(sentence):
    #split into words
    return re.findall(r'\b[^\s]+\b', sentence)

def correct_word(word, dictionary):
    # Compute Levenshtein distance for each word in the dictionary
    distances = [(candidate, textdistance.levenshtein(word, candidate)) for candidate in dictionary]
    # Sort by distance (ascending)
    distances = sorted(distances, key=lambda x: x[1])
    # Return the closest match
    return distances[0][0] if distances else word

def correct_sentence(tokens, dictionary):
    corrected_tokens = [correct_word(token, dictionary) for token in tokens]
    return ' '.join(corrected_tokens)

data = load_dataset()
# Tokenize the original and spelling error sentences
data['Original Tokens'] = data['Original Sentence'].apply(tokenize_sentence)
data['Spelling Error Tokens'] = data['Spelling Error'].apply(tokenize_sentence)
print(data[['Original Tokens', 'Spelling Error Tokens']].head())

# Create a dictionary of unique words from the original sentences
unique_words = set(word for sentence in data['Original Tokens'] for word in sentence)

# Test the correction function
sample_error = data['Spelling Error Tokens'][0]
corrected = correct_sentence(sample_error, unique_words)
print("Original Error:", sample_error)
print("Corrected Sentence:", corrected)
# Out:
#              Original Sentence            Spelling Error  \
# 0                  මම ගමට යමි.                මම ගට යමි.
# 1             ඔහු පාසලට ගියේය.            ඔහු පසලට ගියය.
# 2          අපි ගඟේ දිය නෑවෙමු.         අ ගඟේ දිය නෑවෙමු.
# 3  ඔවුන් විභාගය ජයග්‍රහණය කළහ.  ඔවන විභාගය ජයග්‍හණය කළහ.
# 4              ඔහු ගෙදරට ආවේය.           ඔහු ගෙදරට ආවේය.
#
#                   Grammar Error
# 0                  මම ගමට යනවා.
# 1                ඔහු පාසලට ගිය.
# 2            අපි ගඟේ දිය නෑවෙම.
# 3  ඔවුන් විභාගය ජයග්‍රහණය කළමු.
# 4              ඔහු ගෙදරට ආවායය.
#                   Original Tokens         Spelling Error Tokens
# 0                   [මම, ගමට, යම]                  [මම, ගට, යම]
# 1              [ඔහ, පාසලට, ගියේය]              [ඔහ, පසලට, ගියය]
# 2            [අප, ගඟ, දිය, නෑවෙම]           [අ, ගඟ, දිය, නෑවෙම]
# 3  [ඔවුන, විභාගය, ජයග්‍රහණය, කළහ]  [ඔවන, විභාගය, ජයග්‍හණය, කළහ]
# 4               [ඔහ, ගෙදරට, ආවේය]             [ඔහ, ගෙදරට, ආවේය]
# Original Error: ['මම', 'ගට', 'යම']
# Corrected Sentence: මම ගත යම

# %%
# Apply the spell checker to all sentences with spelling errors
data['Corrected Spelling Error'] = data['Spelling Error Tokens'].apply(lambda x: correct_sentence(x, unique_words))

# Evaluate the corrections
print(data[['Spelling Error', 'Corrected Spelling Error', 'Original Sentence']].head())
# Out:
#              Spelling Error   Corrected Spelling Error  \
# 0                මම ගට යමි.                   මම ගත යම
# 1            ඔහු පසලට ගියය.             ඔහ පාසලට ගියේය
# 2         අ ගඟේ දිය නෑවෙමු.            අප ගඟ දිය නෑවෙම
# 3  ඔවන විභාගය ජයග්‍හණය කළහ.  ඔවුන විභාගය ජයග්‍රහණය කළහ
# 4           ඔහු ගෙදරට ආවේය.              ඔහ ගෙදරට ආවේය
#
#              Original Sentence
# 0                  මම ගමට යමි.
# 1             ඔහු පාසලට ගියේය.
# 2          අපි ගඟේ දිය නෑවෙමු.
# 3  ඔවුන් විභාගය ජයග්‍රහණය කළහ.
# 4              ඔහු ගෙදරට ආවේය.

# %%
def calculate_accuracy(original_sentences, corrected_sentences):
    # Initialize counters
    word_correct = 0
    word_total = 0
    sentence_correct = 0
    sentence_total = len(original_sentences)

    for original, corrected in zip(original_sentences, corrected_sentences):
        # Tokenize both sentences
        original_tokens = tokenize_sentence(original)
        corrected_tokens = tokenize_sentence(corrected)
        
        # Word-level accuracy
        for orig_word, corr_word in zip(original_tokens, corrected_tokens):
            word_total += 1
            if orig_word == corr_word:
                word_correct += 1

        # Sentence-level accuracy
        if original == corrected:
            sentence_correct += 1

    # Calculate percentages
    word_accuracy = (word_correct / word_total) * 100 if word_total > 0 else 0
    return word_accuracy
# Evaluate accuracy of the spell checker
original_sentences = data['Original Sentence']
corrected_sentences = data['Corrected Spelling Error']

word_accuracy = calculate_accuracy(original_sentences, corrected_sentences)

print(f"Word-Level Accuracy: {word_accuracy:.2f}%")
# Out:
# Word-Level Accuracy: 92.24%

# %%
def correct_word(word, dictionary):
    # Compute Levenshtein distance for each word in the dictionary
    distances = [(candidate, textdistance.levenshtein(word, candidate)) for candidate in dictionary]
    # Sort by distance (ascending)
    distances = sorted(distances, key=lambda x: x[1])
    # Return the closest match
    return (word, distances[0][0]) if distances else (word, word)  # Return the original word if no match found

def correct_sentence(tokens, dictionary):
    # Correct each word and collect mistakes
    corrections = [correct_word(token, dictionary) for token in tokens]
    corrected_tokens = [correct[1] for correct in corrections]
    mistakes = [(original, corrected) for original, corrected in corrections if original != corrected]
    return ' '.join(corrected_tokens), mistakes

# Apply the spell checker and collect mistakes
data['Corrected Spelling Error'], data['Mistakes'] = zip(
    *data['Spelling Error Tokens'].apply(lambda x: correct_sentence(x, unique_words))
)

# Print spelling mistakes and corrections
for index, row in data.iterrows():
    print(f"Sentence {index + 1}:")
    print(f"  Spelling Mistakes and Corrections: {row['Mistakes']}")
    print(f"  Corrected Sentence: {row['Corrected Spelling Error']}")
    print()
# Out:
# Sentence 1:
#   Spelling Mistakes and Corrections: [('ගට', 'ගත')]
#   Corrected Sentence: මම ගත යම
#
# Sentence 2:
#   Spelling Mistakes and Corrections: [('පසලට', 'පාසලට'), ('ගියය', 'ගියේය')]
#   Corrected Sentence: ඔහ පාසලට ගියේය
#
# Sentence 3:
#   Spelling Mistakes and Corrections: [('අ', 'අප')]
#   Corrected Sentence: අප ගඟ දිය නෑවෙම
#
# Sentence 4:
#   Spelling Mistakes and Corrections: [('ඔවන', 'ඔවුන'), ('ජයග්\u200dහණය', 'ජයග්\u200dරහණය')]
#   Corrected Sentence: ඔවුන විභාගය ජයග්‍රහණය කළහ
#
# Sentence 5:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ඔහ ගෙදරට ආවේය
#
# Sentence 6:
#   Spelling Mistakes and Corrections: [('ගැන්වීය', 'ඉගැන්වීය')]
#   Corrected Sentence: ගුරුවරය පාඩම ඉගැන්වීය
#
# Sentence 7:
#   Spelling Mistakes and Corrections: [('වර්ධය', 'වර්ධනය')]
#   Corrected Sentence: ම නගරය වර්ධනය ව
#
# Sentence 8:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: මග මිතුර ම උදව කළේය
#
# Sentence 9:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: අප පාසල ප්‍රථම ස්ථානයට පැමිණිය
#
# Sentence 10:
#   Spelling Mistakes and Corrections: [('ඔව', 'ඔහ')]
#   Corrected Sentence: ඔහ ව්‍යාපෘතිය සාර්ථකව නිම කළහ
#
# Sentence 11:
#   Spelling Mistakes and Corrections: [('පත', 'ඉත')]
#   Corrected Sentence: ම ඉත හොඳය
#
# Sentence 12:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: මම අද පාසලට යම
#
# Sentence 13:
#   Spelling Mistakes and Corrections: [('සතට', 'සතුට')]
#   Corrected Sentence: ගමන අවසානය අප සතුට වියෙම
#
# Sentence 14:
#   Spelling Mistakes and Corrections: [('මිතුග', 'මිතුර')]
#   Corrected Sentence: ඔබග මිතුර නම කුමක්ද
#
# Sentence 15:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ඔවුන රැකියාව ආරම්භ කළහ
#
# Sentence 16:
#   Spelling Mistakes and Corrections: [('ගැටලව', 'ගැටලුව')]
#   Corrected Sentence: මම ගැටලුව පිළිබඳව විස්තර කළෙම
#
# Sentence 17:
#   Spelling Mistakes and Corrections: [('සාරථක', 'සාර්ථක')]
#   Corrected Sentence: ගමන සාර්ථක විය
#
# Sentence 18:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: අපිට නව ව්‍යාපෘතිය ලැබුන
#
# Sentence 19:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: මම ගෘහස්ත කාර්යය ඉක්මනින නම කළෙම
#
# Sentence 20:
#   Spelling Mistakes and Corrections: [('සාරථක', 'සාර්ථක')]
#   Corrected Sentence: ඔහුග පරීක්ෂණය සාර්ථක විය
#
# Sentence 21:
#   Spelling Mistakes and Corrections: [('ටහන', 'සටහන')]
#   Corrected Sentence: මග නම ලේඛනය සටහන ව
#
# Sentence 22:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: අප ගමනේද ගිගුම සහිත වැස දැක්කෙම
#
# Sentence 23:
#   Spelling Mistakes and Corrections: [('ඔවුනග', 'ඔවුන'), ('විශේෂය', 'විශේෂණය'), ('සහන', 'සදහන')]
#   Corrected Sentence: ඔවුන විශේෂණය හොඳින සදහන ව
#
# Sentence 24:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ම ගඟ දිය ගලය
#
# Sentence 25:
#   Spelling Mistakes and Corrections: [('ගහස්ත', 'ගෘහස්ත')]
#   Corrected Sentence: ඔවුන විසින ගෘහස්ත කාර්යය සාර්ථකව කළහ
#
# Sentence 26:
#   Spelling Mistakes and Corrections: [('සිටත', 'සිටිත')]
#   Corrected Sentence: අප පවුල සතුන ඉත සන්තෝසයෙන සිටිත
#
# Sentence 27:
#   Spelling Mistakes and Corrections: [('නිවරද', 'නිවැරද')]
#   Corrected Sentence: ඔහුග ප්‍රකාශය නිවැරද ව
#
# Sentence 28:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: අප අලුත මාර්ගය පරීක්ෂ කළෙම
#
# Sentence 29:
#   Spelling Mistakes and Corrections: [('ලේඛය', 'ලේඛනය')]
#   Corrected Sentence: ඔබග නම ලේඛනය දැක්කාද
#
# Sentence 30:
#   Spelling Mistakes and Corrections: [('ඔවුනග', 'ඔවුන'), ('සාර්කය', 'සාර්ථකය')]
#   Corrected Sentence: ඔවුන ජීවිත සාර්ථකය
#
# Sentence 31:
#   Spelling Mistakes and Corrections: [('ගහස්ත', 'ගෘහස්ත')]
#   Corrected Sentence: මම ගෘහස්ත කාර්යය සාර්ථකව නිම කළෙම
#
# Sentence 32:
#   Spelling Mistakes and Corrections: [('නාට්\u200dයක', 'නාට්\u200dයයක')]
#   Corrected Sentence: අද පාසල අවසානය නාට්‍යයක පැවැත්විණ
#
# Sentence 33:
#   Spelling Mistakes and Corrections: [('අවශ්\u200dතාවය', 'අවශ්\u200dයතාවය')]
#   Corrected Sentence: ඔහුගෙන වටින අවශ්‍යතාවය ලබ ගත හැකිය
#
# Sentence 34:
#   Spelling Mistakes and Corrections: [('හහ', 'ඔහ')]
#   Corrected Sentence: අප නගරය ප්‍රධාන මාර්ගය ඔහ ගියෙම
#
# Sentence 35:
#   Spelling Mistakes and Corrections: [('ඔවුනග', 'ඔවුන'), ('ව්\u200dයාපතිය', 'ව්\u200dයාපෘතිය')]
#   Corrected Sentence: ඔවුන ව්‍යාපෘතිය සාර්ථකය
#
# Sentence 36:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: ම කාර්යය ඉත සාර්ථක විය
#
# Sentence 37:
#   Spelling Mistakes and Corrections: [('ව්\u200dයපාරයක', 'ව්\u200dයාපාරයක')]
#   Corrected Sentence: ඔවුන නව ව්‍යාපාරයක ආරම්භ කළහ
#
# Sentence 38:
#   Spelling Mistakes and Corrections: []
#   Corrected Sentence: අප ගඟ අසල ගොවිපොළක පැමිණෙම
#
# Sentence 39:
#   Spelling Mistakes and Corrections: [('සාරථක', 'සාර්ථක')]
#   Corrected Sentence: ඔහුග ගමන සාර්ථක විය
#
# Sentence 40:
#   Spelling Mistakes and Corrections: [('කළම', 'කළහ')]
#   Corrected Sentence: අප පසුගිය මාසය ගමන කළහ
#
# Sentence 41:
#   Spelling Mistakes and Corrections: [('ඔවුනග', 'ඔවුන'), ('නායකතවය', 'නායකත්වය')]
#   Corrected Sentence: ඔවුන නායකත්වය සාර්ථකය
#
# Sentence 42:
#   Spelling Mistakes and Corrections: [('කාර්ක', 'කාර්යය')]
#   Corrected Sentence: මම නව කාර්යය ආරම්භ කළෙම
#
# Sentence 43:
#   Spelling Mistakes and Corrections: [('ඔවුනග', 'ඔවුන'), ('සාථකය', 'සාර්ථකය')]
#   Corrected Sentence: ඔවුන දායකත්වය සාර්ථකය
#
# Sentence 44:
#   Spelling Mistakes and Corrections: [('අලත', 'අලුත')]
#   Corrected Sentence: අප අලුත මාර්ගයක ගමන කළෙම
#
# Sentence 45:
#   Spelling Mistakes and Corrections: [('නවැරද', 'නිවැරද')]
#   Corrected Sentence: ඔහුග වාර්තාව නිවැරද ව
#
# Sentence 46:
#   Spelling Mistakes and Corrections: [('ගමනද', 'ගමන'), ('ගැළ', 'ගැටළ')]
#   Corrected Sentence: අප ගමන ගැටළ කිසිවක නොතිබුණ
#
# Sentence 47:
#   Spelling Mistakes and Corrections: [('සාර්ක', 'සාර්ථක')]
#   Corrected Sentence: ඔවුන සාර්ථක ව්‍යාපාරයක ගොඩනැගීය
#
# Sentence 48:
#   Spelling Mistakes and Corrections: [('සාර්ක', 'සාර්ථක')]
#   Corrected Sentence: ම කාර්යය ඉත සාර්ථක විය
#
# Sentence 49:
#   Spelling Mistakes and Corrections: [('ජීතය', 'ජීවිතය')]
#   Corrected Sentence: ඔහුග ජීවිතය සාර්ථකය
#
# Sentence 50:
#   Spelling Mistakes and Corrections: [('සිටිම', 'සිටිත')]
#   Corrected Sentence: අප සතුටින සිටිත
